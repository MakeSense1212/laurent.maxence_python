# %% [markdown]
# # Commande de base pour démarrer

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# # Les attributions et créations de variables

# %%
ma_variable = "string" #String
ma_variable2 = 1 #Int
milliers =  1000.0 #Float

# %%
print(str(milliers))
mon_integer = int(milliers)
# Out:
# 1000.0

# %%
ma_variable3 = input("Press the enter key to exit") #Permet de récupérer les inputs clavier
print(ma_variable3)
# Out:
# Press the enter key to exit

# %% [markdown]
# # Listes, array ...

# %%
ma_liste = ['un', 'deux', 'trois']
print(ma_liste)
print(ma_liste[0])
print(ma_liste[1:3])
print(ma_liste[2:])
# Out:
# ['un', 'deux', 'trois']
# un
# ['deux', 'trois']
# ['trois']

# %% [markdown]
# # Dictionnaires

# %%
dict = {}
dict['one'] = "This is one"
dict['two'] = "This is two"

print(dict['one'])
print(dict.keys())
print(dict.values())
# Out:
# This is one
# dict_keys(['one', 'two'])
# dict_values(['This is one', 'This is two'])

# %% [markdown]
# #  Travail avec des fichiers

# %%
contenu = open("maliste.txt", "r")
for ligne in contenu:
    print(ligne)
# Out:
# test
#
# bonjour

# %%
with open("maliste.txt", "r", encoding='utf-8') as infile:
    for line in infile:
        if line.startswith('Manu'):
            print("J'ai retrouvé le prof")
# Out:
# J'ai retrouvé le prof

# %%
var = 1000
if(var==1000): print ("Value of expression 100")
    
if(var < 1200):
    print("smicard !")
elif(var < 9000):
    print("average !")
else:
    print("He's over nine  thousaands !!")
# Out:
# Value of expression 100
# smicard !

# %% [markdown]
# # Structure for

# %%
for letter in 'Python':
    print('Current letter :', letter)
# Out:
# Current letter : P
# Current letter : y
# Current letter : t
# Current letter : h
# Current letter : o
# Current letter : n

# %%
fruits = ['banana', 'apple', 'mango']
for fruit in fruits:
    print('Current fruit :', fruit)
# Out:
# Current fruit : banana
# Current fruit : apple
# Current fruit : mango

# %%
count = 0
while (count < 9):
    print ('The count is:', count)
    count += 1
# Out:
# The count is: 0
# The count is: 1
# The count is: 2
# The count is: 3
# The count is: 4
# The count is: 5
# The count is: 6
# The count is: 7
# The count is: 8

# %% [markdown]
# # Les fonctions

# %%
def bonjour_vous(nom):
    print("Bonjour : ", nom)
    return

bonjour_vous("Maxence")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-51ed447c26c5> in <module>
#       3     return
#       4
# ----> 5 bonjour_vous("Maxence")
#
# NameError: name 'bonjour_vous' is not defined
